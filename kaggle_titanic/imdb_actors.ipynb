# %%
import pandas as pd

# %%
df = pd.read_csv("file", delimiter="    ")
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:639: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
df
# Out:
#                   McClure, Marc (I)\tFreaky Friday\t2003
# 0                  McClure, Marc (I)\tCoach Carter\t2005
# 1                   McClure, Marc (I)\tSuperman II\t1980
# 2                     McClure, Marc (I)\tApollo 13\t1995
# 3                      McClure, Marc (I)\tSuperman\t1978
# 4            McClure, Marc (I)\tBack to the Future\t1985
# 5      McClure, Marc (I)\tBack to the Future Part III...
# 6            Cooper, Chris (I)\tMe, Myself & Irene\t2000
# 7                   Cooper, Chris (I)\tOctober Sky\t1999
# 8                        Cooper, Chris (I)\tCapote\t2005
# 9          Cooper, Chris (I)\tThe Bourne Supremacy\t2004
# 10                  Cooper, Chris (I)\tThe Patriot\t2000
# 11                     Cooper, Chris (I)\tThe Town\t2010
# 12                   Cooper, Chris (I)\tSeabiscuit\t2003
# 13               Cooper, Chris (I)\tA Time to Kill\t1996
# 14     Cooper, Chris (I)\tWhere the Wild Things Are\t...
# ...

# %%
import csv

# %%
f= csv.reader("file",delimiter="\t")

# %%
for lines in f:
    print lines
# Out:
# ['f']
# ['i']
# ['l']
# ['e']
